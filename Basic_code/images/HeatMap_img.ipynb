# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('E:\FYP\code\solar_plate_0.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(image)

# %%
# Apply a colormap
heatmap = cv2.applyColorMap(image, cv2.COLORMAP_JET)
plt.imshow(heatmap)
plt.show()

# %%
heatmap
# Out:
# array([[[  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128],
#         ...,
#         [  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128]],
#
#        [[  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128],
#         ...,
#         [  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128]],
#
#        [[  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128],
#         ...,
#         [  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128]],
#
#        ...,
#
#        [[  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128],
#         ...,
#         [  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128]],
#
#        [[  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128],
#         ...,
#         [  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128]],
#
#        [[  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128],
#         ...,
#         [  0,   0, 128],
#         [  0,   0, 128],
#         [  0,   0, 128]]], dtype=uint8)

# %%
# Preprocess the image (for example, apply thresholding)
_, thresh = cv2.threshold(heatmap, 150, 255, cv2.THRESH_BINARY)

# %%
# Find contours
contours, herierchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# Create a list to store the cropped solar plates
cropped_plates = []

# Iterate through each contour
for contour in contours:
    # Get the bounding box of the contour
    x, y, w, h = cv2.boundingRect(contour)
    
    # Crop the solar plate from the original image
    cropped_plate = image[y:y+h, x:x+w]
    
    # Add the cropped plate to the list
    cropped_plates.append(cropped_plate)

# %%
cropped_plate
plt.imshow(cropped_plate)

# %%
# Display the cropped plates (optional)
for i, plate in enumerate(cropped_plates):
    plt.imshow(plate)
    print(plate[i])
# Out:
# [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  ...
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]]

# %%
import cv2
import numpy as np
# Load the image
image = cv2.imread('E:\FYP\code\images\single_plate.png')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Preprocess the image (for example, apply thresholding)
_, thresh = cv2.threshold(gray_image, 150, 255, cv2.THRESH_BINARY)

# Find contours
contours, _ = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Create a list to store the cropped solar plates
cropped_plates = []

# Iterate through each contour
for contour in contours:
    # Get the bounding box of the contour
    x, y, w, h = cv2.boundingRect(contour)
    
    # Crop the solar plate from the original image
    cropped_plate = image[y:y+h, x:x+w]
    
    # Add the cropped plate to the list
    cropped_plates.append(cropped_plate)

# Display the cropped plates (optional)
for i, plate in enumerate(cropped_plates):
    plt.imshow(plate)
