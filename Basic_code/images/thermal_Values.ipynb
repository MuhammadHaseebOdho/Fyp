# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the thermal image
thermal_image = cv2.imread('E:\FYP\code\images\img1.jpg', cv2.IMREAD_GRAYSCALE)

# %%
# Feature Extraction: Get thermal values from the entire thermal image
thermal_values_full = thermal_image.flatten()

# %%
# Create a list to store the cropped solar plates
cropped_plates = []

# Iterate through each contour
for contour in contours:
    # Get the bounding box of the contour
    x, y, w, h = cv2.boundingRect(contour)
    
    # Crop the solar plate from the original image
    cropped_plate = image[y:y+h, x:x+w]
    
    # Add the cropped plate to the list
    cropped_plates.append(cropped_plate)

# %%
# Now you have the thermal values of the entire thermal image in the 'thermal_values_full' array

# Optional: Display the thermal image
# cv2.imshow('Thermal Image', thermal_image)
plt.imshow(thermal_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
print(thermal_image)
# Out:
# [[114  98 120 ... 130 130 130]
#  [ 93  92 124 ... 130 130 130]
#  [ 94 106 138 ... 130 130 130]
#  ...
#  [ 45  42  36 ...  13  12  10]
#  [ 43  40  33 ...  13  12  10]
#  [ 40  37  32 ...  14  12   9]]

# %%
thermal_image.shape
# Out:
# (800, 1200)
